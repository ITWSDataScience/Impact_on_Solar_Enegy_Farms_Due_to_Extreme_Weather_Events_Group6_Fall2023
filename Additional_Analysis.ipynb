# %% [markdown]
# # START FROM HERE

# %%
df = pd.read_csv('cali_powerplant_out_1/combined_solar_risk_by_day_updated.csv')

# %%
disasters_list = list(set(df['EXPANDED_DISASTER']))

# %%
disasters_list
# Out:
# ['Windstorm',
#  'Flooding',
#  'Severe winter storms',
#  'Rainstorms',
#  'Winter Storms',
#  'Wildfires',
#  'Fires',
#  'Earthquakes',
#  'Drought',
#  'Storms']

# %%
import seaborn as sns

# %%
df_LR = pd.get_dummies(df, columns = ['EXPANDED_DISASTER'], dtype=float)

# %%
temp_cor = df_LR.corr()

for col in temp_cor.columns:
    temp_cor[col] = round(temp_cor[col],2)
# Out:
# /var/folders/7k/9hch0q794xqdgy99gw9ytbgw0000gn/T/ipykernel_4303/2736896555.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   temp_cor = df_LR.corr()

# %%
temp_cor
# Out:
#                                              LAT   LON  YEAR    MO    DY  \
# LAT                                         1.00 -0.90  0.07 -0.06 -0.00
# LON                                        -0.90  1.00 -0.06  0.07 -0.00
# YEAR                                        0.07 -0.06  1.00  0.67  0.29
# MO                                         -0.06  0.07  0.67  1.00  0.44
# DY                                         -0.00 -0.00  0.29  0.44  1.00
# ALLSKY_SFC_SW_DWN                          -0.03  0.04  0.18  0.06 -0.31
# RISK_VALUE                                 -0.49  0.44  0.00  0.13  0.03
# RISK_SCORE                                 -0.54  0.46 -0.06  0.06 -0.01
# AREA                                       -0.48  0.62 -0.05  0.01 -0.05
# EXPANDED_DISASTER_Drought                   0.13 -0.14 -0.15 -0.29 -0.33
# EXPANDED_DISASTER_Earthquake                0.09 -0.11 -0.10  0.01  0.08
# EXPANDED_DISASTER_Earthquakes              -0.11  0.13  0.00 -0.02 -0.09
# ...

# %%
import seaborn as sns

sns.set(rc={'figure.figsize':(20,20)})
dataplot = sns.heatmap(temp_cor.corr(), cmap="YlGnBu", annot=True)
